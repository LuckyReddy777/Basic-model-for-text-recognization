# %%
# !pip install torch torchvision torchaudio numpy
# !pip install easyocr
# Out:
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# ...

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img_path="print 01.jpg"

# %%
img = cv2.imread(img_path)
plt.imshow(img)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(img_path)
result[4]
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ([[956, 124], [1090, 124], [1090, 176], [956, 176]],
#  'IDEAS',
#  0.9991026579412158)

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[4][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(img_path)
img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
img = cv2.putText(img, text, top_left, font, 5, (255,0,0), 4)
plt.figure(figsize = (10,10))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(img_path)
for line in result:
    t_left = tuple([int(x) for x in line[0][0]])
    b_right = tuple([int(x) for x in line[0][2]])
    text = line[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, t_left, b_right, (0,255,0), 5)
    img = cv2.putText(img, text, t_left, font, 5, (255,0,0), 4)
    
plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

# %%
img_path="WhatsApp Image 2022-02-18 at 14.22.57.jpeg"

# %%
img = cv2.imread(img_path)
plt.imshow(img)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(img_path)
result[4]
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ([[109, 466], [510, 466], [510, 519], [109, 519]],
#  'Mahad-402302, Maharashtra',
#  0.8250357191639722)

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[4][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(img_path)
img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
img = cv2.putText(img, text, top_left, font, 5, (255,0,0), 4)
plt.figure(figsize = (10,10))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(img_path)
for line in result:
    t_left = tuple([int(x) for x in line[0][0]])
    b_right = tuple([int(x) for x in line[0][2]])
    text = line[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, t_left, b_right, (0,255,0), 5)
    img = cv2.putText(img, text, t_left, font, 5, (255,0,0), 4)
    
plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()
